# %%
import pandas as pd
# 呈现图表效果导包，引入相关配置文件
from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB

# %%
# 读取数据表格
df = pd.read_csv('data.csv')
df.head()
# Out:
#                      职位               公司               薪资  年薪  城市  区域    经验  \
# 0  python开发工程师(双休+五险一金）  深圳市法本信息技术股份有限公司          1.5万-2万  12  上海  浦东  3-5年
# 1           python软件工程师       上海凯来仪器有限公司    1.1万-2万 · 14薪  14  上海  浦东  3-5年
# 2           Python后端工程师              中富通  1.5万-2.5万 · 13薪  13  上海  杨浦  3-5年
# 3           python爬虫工程师  深圳市法本信息技术股份有限公司        1.5万-2.5万  12  上海  浦东  3-5年
# 4           python开发工程师     上海从开网络科技有限公司        1.2万-1.7万  12  上海  浦东  3-5年
#
#    学历  公司性质        公司规模                                    标签
# 0  本科  上市公司  1000-9999人               Python web框架.Python并发框架
# 1  本科    民营      20-99人     Python并发框架.Python可视化库.后端开发.图形图像处理
# 2  本科  上市公司  1000-9999人  Python.TypeScript.Django.Flask.MySQL
# 3  本科  上市公司  1000-9999人                                   NaN
# 4  大专    民营    100-299人          Python web框架.Python并发框架.后端开发

# %%
# 划分数据
area_info = df['区域'].value_counts().index.to_list()
area_num = df['区域'].value_counts().to_list()
exp_info = df['经验'].value_counts().index.to_list()
exp_num = df['经验'].value_counts().to_list()
cop_info = df['公司性质'].value_counts().index.to_list()
cop_num = df['公司性质'].value_counts().to_list()

# %%
# 引用Github上的开源pyecharts画廊里的可视化代码，进行相关数据的可视化操作
# 官方网址：https://gallery.pyecharts.org/#/
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add(
        "",
        [
            list(z)
            for z in zip(
                area_info,
                area_num,
            )
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="上海Python岗位招聘区域分布情况"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    # 保存html文件
    .render("【智联招聘】可视化-区域信息饼状图.html")
)
# 也可以选择直接在jupyter上呈现图表效果
# 在jupyter上呈现图形效果
# c.load_javascript()

# %%
# c.render_notebook()

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add(
        "",
        [
            list(z)
            for z in zip(
                exp_info,
                exp_num,
            )
        ],
        center=["40%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="上海Python岗位招聘经验要求情况"),
        legend_opts=opts.LegendOpts(type_="scroll", pos_left="80%", orient="vertical"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    # 保存html文件
    .render("【智联招聘】可视化-经验要求信息饼状图.html")
)

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

"""
Gallery 使用 pyecharts 1.1.0
参考地址: https://echarts.apache.org/examples/editor.html?c=line-simple

目前无法实现的功能:

暂无
"""

(
    Line()
    .set_global_opts(
        tooltip_opts=opts.TooltipOpts(is_show=False),
        xaxis_opts=opts.AxisOpts(type_="category"),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    )
    .add_xaxis(xaxis_data=cop_info)
    .add_yaxis(
        series_name="",
        y_axis=cop_num,
        symbol="emptyCircle",
        is_symbol_show=True,
        label_opts=opts.LabelOpts(is_show=False),
    )
    .render("【智联招聘】可视化-公司性质情况.html")
)
# Out:
# 'd:\\Pytorch_机器学习与深度学习\\数据爬取、可视化、分析实战\\【智联招聘】招聘信息数据分析项目\\【智联招聘】可视化-公司性质情况.html'
